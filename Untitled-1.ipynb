# %%
<!DOCTYPE html>
<html lang="ar">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>متجر العبايات</title>
<link rel="stylesheet" href="style.css">
</head>
<body>

<header>
<h1>متجر العبايات</h1>
<button onclick="openCart()">🛒 السلة (<span id="cart-count">0</span>)</button>
</header>

<section class="products">
<div class="product">
<img src="https://via.placeholder.com/200">
<h3>عباية سوداء فخمة</h3>
<p>299 درهم</p>
<button onclick="addToCart('عباية سوداء',299)">اشتر الآن</button>
</div>

<div class="product">
<img src="https://via.placeholder.com/200">
<h3>عباية مفتوحة أنيقة</h3>
<p>349 درهم</p>
<button onclick="addToCart('عباية مفتوحة',349)">اشتر الآن</button>
</div>
</section>

<div id="cart" class="cart">
<h2>سلة الشراء</h2>
<div id="cart-items"></div>

<input placeholder="الاسم" id="name">
<input placeholder="الهاتف" id="phone">
<input placeholder="العنوان" id="address">

<button onclick="sendOrder()">تأكيد الطلب</button>
<button onclick="closeCart()">إغلاق</button>
</div>

<script src="script.js"></script>
</body>
</html>
